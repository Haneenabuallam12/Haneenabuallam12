# %% [markdown]
# <a href="https://colab.research.google.com/github/Haneenabuallam12/Haneenabuallam12/blob/main/W2Day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("kickstarter_sample.csv", index_col ='created_at' , parse_dates=True)
print(df)
# Out:
#                      backers_count  ...       usd_type
# created_at                          ...
# 2009-04-25 05:37:50             25  ...  international
# 2009-08-25 18:21:02             36  ...  international
# 2009-08-30 16:57:43             82  ...  international
# 2009-09-14 23:58:49             10  ...  international
# 2009-10-11 20:28:44            156  ...  international
# ...                            ...  ...            ...
# 2021-05-08 19:57:26              4  ...  international
# 2021-05-08 19:57:26              4  ...  international
# 2021-05-09 04:06:34             18  ...  international
# 2021-05-09 14:32:09              1  ...  international
# 2021-05-10 02:24:04              2  ...  international
#
# [6958 rows x 38 columns]

# %%
df
# Out:
#                      backers_count  ...       usd_type
# created_at                          ...
# 2009-04-25 05:37:50             25  ...  international
# 2009-08-25 18:21:02             36  ...  international
# 2009-08-30 16:57:43             82  ...  international
# 2009-09-14 23:58:49             10  ...  international
# 2009-10-11 20:28:44            156  ...  international
# ...                            ...  ...            ...
# 2021-05-08 19:57:26              4  ...  international
# 2021-05-08 19:57:26              4  ...  international
# 2021-05-09 04:06:34             18  ...  international
# 2021-05-09 14:32:09              1  ...  international
# 2021-05-10 02:24:04              2  ...  international
#
# [6958 rows x 38 columns]

# %%
df= df.loc['2018-01-01':'2021-12-30']

# %%
df=df[['backers_count','blurb','country','usd_pledged','state']]

# %%
df = df[:-3]
df
# Out:
#                      backers_count  ...       state
# created_at                          ...
# 2018-01-01 00:37:02             15  ...  successful
# 2018-01-02 12:04:32             13  ...  successful
# 2018-01-02 21:51:43            331  ...  successful
# 2018-01-02 22:04:22            124  ...  successful
# 2018-01-02 23:45:25            105  ...  successful
# ...                            ...  ...         ...
# 2021-05-07 10:52:48             96  ...        live
# 2021-05-08 03:26:51              2  ...        live
# 2021-05-08 14:10:42              1  ...        live
# 2021-05-08 19:57:26              4  ...        live
# 2021-05-08 19:57:26              4  ...        live
#
# [3688 rows x 5 columns]

# %%
total_backers= d["backers_count"].sum()
total_backers
# Out:
# 1512228

# %%
ongoing_df = df[df["state"]== "live" ]
    
concluded_df = df[df['state']== "successful"]

# %%
ongoing_df
# Out:
#                      backers_count  ... state
# created_at                          ...
# 2019-06-16 17:01:18              5  ...  live
# 2019-10-18 19:40:19            417  ...  live
# 2020-01-02 03:57:12             21  ...  live
# 2020-02-21 16:34:59            740  ...  live
# 2020-03-19 21:16:07              2  ...  live
# ...                            ...  ...   ...
# 2021-05-07 10:52:48             96  ...  live
# 2021-05-08 03:26:51              2  ...  live
# 2021-05-08 14:10:42              1  ...  live
# 2021-05-08 19:57:26              4  ...  live
# 2021-05-08 19:57:26              4  ...  live
#
# [306 rows x 5 columns]

# %%
concluded_df
# Out:
#                      backers_count  ...       state
# created_at                          ...
# 2018-01-01 00:37:02             15  ...  successful
# 2018-01-02 12:04:32             13  ...  successful
# 2018-01-02 21:51:43            331  ...  successful
# 2018-01-02 22:04:22            124  ...  successful
# 2018-01-02 23:45:25            105  ...  successful
# ...                            ...  ...         ...
# 2021-04-07 17:43:59             81  ...  successful
# 2021-04-07 17:55:05            150  ...  successful
# 2021-04-07 21:39:39             63  ...  successful
# 2021-04-12 22:07:03             17  ...  successful
# 2021-04-13 11:31:04            175  ...  successful
#
# [3382 rows x 5 columns]

# %%
ongoing_avg_funding = ongoing_df["usd_pledged"].mean()
concluded_avg_funding = concluded_df["usd_pledged"].mean()
ongoing_total_backers = ongoing_df["backers_count"].sum()
concluded_total_backers = concluded_df["backers_count"].sum()

# %%
print(f"The average funding for live projects: {ongoing_avg_funding}")
print(f"The average funding for successful projects: {concluded_avg_funding}")

print(f"The total number of backers for live projects: {ongoing_total_backers}")
print(f"The total number of backers for successful projects: {concluded_total_backers}")
# Out:
# The average funding for live projects: 19135.545897625172
# The average funding for successful projects: 23260.83307026567
# The total number of backers for live projects: 90347
# The total number of backers for successful projects: 881172

# %%
concluded_df["country"].hist()
ongoing_df["country"].hist()
